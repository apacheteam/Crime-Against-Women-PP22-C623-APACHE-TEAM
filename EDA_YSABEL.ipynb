# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt, seaborn as sb

# %%
df = pd.read_csv('C:/Users/HP/Documents/Hamoye/TRial/Crime-Against-Women-PP22-C623-APACHE-TEAM/crimes_against_women_2001-2014.csv')

# %%
df.head()
# Out:
#    sr_no        state/ut       district  year  rape  kidnapping_and_abduction  \
# 0      0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1      1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2      2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3      3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4      4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    dowry_deaths  assault_on_women  insult_to_modesty  \
# 0            16               149                 34
# 1             7               118                 24
# 2            14               112                 83
# 3            17               126                 38
# 4            12               109                 58
#
#    cruelty_by_husband_or_relatives  importation_of_girls
# 0                              175                     0
# 1                              154                     0
# ...

# %%
#the 5 states with a high importation of girls
state = df.groupby('state/ut')['importation_of_girls'].sum()
state = state.sort_values(ascending = False)

#Other states
state['Others']=state[5:].sum()

#Give the five top states and other states
state = state.iloc[[0,1,2,3,4,-1]]
state
# Out:
# state/ut
# BIHAR             452
# JHARKHAND         149
# WEST BENGAL       127
# MADHYA PRADESH     67
# KARNATAKA          47
# Others             94
# Name: importation_of_girls, dtype: int64

# %%
#pie chart 
colors = ['#009ACD', '#C34D1F', '#63D1F4', '#0EBFE9','#C1F0F6', '#00008b']

explode=(0,0,0,0,0,0.2)
fig, ax = plt.subplots(figsize =(10, 7))

plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = '#909090'
plt.rcParams['axes.labelcolor']= '#909090'
plt.rcParams['xtick.color'] = '#909090'
plt.rcParams['ytick.color'] = '#909090'
plt.rcParams['font.size']=12


_, _, autotexts=ax.pie(ser.values,labels=ser.index,colors=colors,labeldistance=1.05, explode = explode,startangle=45, autopct=lambda x:int(x/100.*ser.sum()))
for ins in autotexts:
    ins.set_color('white')
plt.axis('equal')
ax.set_title("                         Top 5 States in India with a High Frequency of Human Trafficking between the years 2002-2014")

ax.legend(bbox_to_anchor =(1, 0, 0.5, 1),loc ="upper left",frameon=False,)

plt.tight_layout()
